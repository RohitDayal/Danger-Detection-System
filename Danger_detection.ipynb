# %%
#Importing the required libraries
import os
import librosa
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.image import resize
from tensorflow.keras.models import load_model
import warnings
from sklearn.metrics import classification_report
from sklearn import metrics
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %%
# Defining the folder structure
data_dir = 'Audio_dataset'
classes = ['Danger', 'Normal']

# %%
# Load and preprocess audio data
def load_and_preprocess_data(data_dir, classes, target_shape=(256, 256)):
    data = []
    labels = []
    for i, class_name in enumerate(classes):
        class_dir = os.path.join(data_dir, class_name)
        for filename in os.listdir(class_dir):
            if filename.endswith('.mp3'):
                file_path = os.path.join(class_dir, filename)
                audio_data, sample_rate = librosa.load(file_path, sr=None)
                mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
                mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), target_shape)
                data.append(mel_spectrogram)
                labels.append(i)
    return np.array(data), np.array(labels)

# %%
# Split data into training and testing sets
data, labels = load_and_preprocess_data(data_dir, classes)
labels = to_categorical(labels, num_classes=len(classes))
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
# Model Creation
input_shape = X_train[0].shape
input_layer = Input(shape=input_shape)
x = Conv2D(32, (3, 3), activation='relu')(input_layer)
x = MaxPooling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = MaxPooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(64, activation='relu')(x)
output_layer = Dense(len(classes), activation='softmax')(x)
model = Model(input_layer, output_layer)

# %%
from keras.utils import plot_model
plot_model(model, show_shapes=True)

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 65ms/step - loss: 0.0920 - accuracy: 0.9743 - val_loss: 2.6973 - val_accuracy: 0.9231
# Epoch 2/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.1571 - accuracy: 0.9871 - val_loss: 2.4538 - val_accuracy: 0.9359
# Epoch 3/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.1618 - accuracy: 0.9871 - val_loss: 2.4502 - val_accuracy: 0.9359
# Epoch 4/50
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2665 - accuracy: 0.9743 - val_loss: 3.3734 - val_accuracy: 0.8974
# Epoch 5/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.3385 - accuracy: 0.9486 - val_loss: 5.6227 - val_accuracy: 0.8718
# Epoch 6/50
# 10/10 [==============================] - 1s 52ms/step - loss: 0.5698 - accuracy: 0.9807 - val_loss: 2.5082 - val_accuracy: 0.8333
# Epoch 7/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.9216 - accuracy: 0.9453 - val_loss: 5.8880 - val_accuracy: 0.8718
# Epoch 8/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.4004 - accuracy: 0.9678 - val_loss: 3.0566 - val_accuracy: 0.8974
# Epoch 9/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.2410 - accuracy: 0.9871 - val_loss: 2.3231 - val_accuracy: 0.9231
# Epoch 10/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1222 - accuracy: 0.9711 - val_loss: 1.9035 - val_accuracy: 0.9359
# Epoch 11/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.0993 - accuracy: 0.9871 - val_loss: 1.9119 - val_accuracy: 0.8205
# Epoch 12/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.8768 - accuracy: 0.9421 - val_loss: 4.3115 - val_accuracy: 0.8718
# Epoch 13/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.2313 - accuracy: 0.9646 - val_loss: 4.4355 - val_accuracy: 0.8846
# Epoch 14/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.5396 - accuracy: 0.9839 - val_loss: 3.8229 - val_accuracy: 0.9103
# Epoch 15/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.3485 - accuracy: 0.9711 - val_loss: 4.0498 - val_accuracy: 0.9103
# Epoch 16/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2672 - accuracy: 0.9807 - val_loss: 3.2147 - val_accuracy: 0.9231
# Epoch 17/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.0865 - accuracy: 0.9582 - val_loss: 3.5382 - val_accuracy: 0.9231
# Epoch 18/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.4129 - accuracy: 0.9871 - val_loss: 4.5823 - val_accuracy: 0.8718
# Epoch 19/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.3417 - accuracy: 0.9646 - val_loss: 3.2168 - val_accuracy: 0.9231
# Epoch 20/50
# 10/10 [==============================] - 1s 61ms/step - loss: 0.5899 - accuracy: 0.9871 - val_loss: 4.7009 - val_accuracy: 0.8718
# Epoch 21/50
# 10/10 [==============================] - 1s 52ms/step - loss: 0.2774 - accuracy: 0.9743 - val_loss: 2.4594 - val_accuracy: 0.9487
# Epoch 22/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.1522 - accuracy: 0.9871 - val_loss: 2.7566 - val_accuracy: 0.9231
# Epoch 23/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0689 - accuracy: 0.9871 - val_loss: 2.6275 - val_accuracy: 0.9231
# Epoch 24/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0961 - accuracy: 0.9743 - val_loss: 3.4747 - val_accuracy: 0.8974
# Epoch 25/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.2877 - accuracy: 0.9871 - val_loss: 2.4553 - val_accuracy: 0.9487
# Epoch 26/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.0715 - accuracy: 0.9871 - val_loss: 2.4688 - val_accuracy: 0.8590
# Epoch 27/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.2711 - accuracy: 0.9711 - val_loss: 2.6237 - val_accuracy: 0.9231
# Epoch 28/50
# 10/10 [==============================] - 1s 52ms/step - loss: 0.0684 - accuracy: 0.9871 - val_loss: 2.6217 - val_accuracy: 0.9231
# Epoch 29/50
# 10/10 [==============================] - 1s 50ms/step - loss: 0.0610 - accuracy: 0.9871 - val_loss: 3.0813 - val_accuracy: 0.9231
# Epoch 30/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.2813 - accuracy: 0.9582 - val_loss: 3.1333 - val_accuracy: 0.9231
# Epoch 31/50
# 10/10 [==============================] - 1s 51ms/step - loss: 1.1687 - accuracy: 0.9646 - val_loss: 5.9432 - val_accuracy: 0.8718
# Epoch 32/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.1747 - accuracy: 0.9743 - val_loss: 3.2980 - val_accuracy: 0.8205
# Epoch 33/50
# 10/10 [==============================] - 1s 51ms/step - loss: 1.2953 - accuracy: 0.9260 - val_loss: 10.9305 - val_accuracy: 0.8590
# Epoch 34/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.7928 - accuracy: 0.9775 - val_loss: 4.2788 - val_accuracy: 0.9231
# Epoch 35/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.5900 - accuracy: 0.9486 - val_loss: 6.0108 - val_accuracy: 0.8718
# Epoch 36/50
# 10/10 [==============================] - 1s 54ms/step - loss: 0.5162 - accuracy: 0.9871 - val_loss: 3.9447 - val_accuracy: 0.9103
# Epoch 37/50
# 10/10 [==============================] - 0s 51ms/step - loss: 0.0967 - accuracy: 0.9839 - val_loss: 2.9933 - val_accuracy: 0.9359
# Epoch 38/50
# 10/10 [==============================] - 1s 53ms/step - loss: 0.0748 - accuracy: 0.9871 - val_loss: 2.7899 - val_accuracy: 0.9487
# Epoch 39/50
# 10/10 [==============================] - 0s 50ms/step - loss: 0.1066 - accuracy: 0.9743 - val_loss: 3.3684 - val_accuracy: 0.9231
# Epoch 40/50
# 10/10 [==============================] - 1s 52ms/step - loss: 0.1215 - accuracy: 0.9807 - val_loss: 2.7334 - val_accuracy: 0.8590
# Epoch 41/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1694 - accuracy: 0.9711 - val_loss: 3.1564 - val_accuracy: 0.9231
# Epoch 42/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.1295 - accuracy: 0.9678 - val_loss: 3.1911 - val_accuracy: 0.9231
# Epoch 43/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.1613 - accuracy: 0.9582 - val_loss: 3.6495 - val_accuracy: 0.9103
# Epoch 44/50
# 10/10 [==============================] - 1s 57ms/step - loss: 0.3052 - accuracy: 0.9871 - val_loss: 3.2042 - val_accuracy: 0.9231
# Epoch 45/50
# 10/10 [==============================] - 1s 58ms/step - loss: 0.2636 - accuracy: 0.9614 - val_loss: 3.8938 - val_accuracy: 0.9103
# Epoch 46/50
# 10/10 [==============================] - 1s 56ms/step - loss: 0.2890 - accuracy: 0.9871 - val_loss: 2.7876 - val_accuracy: 0.9359
# Epoch 47/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.1938 - accuracy: 0.9743 - val_loss: 2.8909 - val_accuracy: 0.9359
# Epoch 48/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0976 - accuracy: 0.9678 - val_loss: 2.6692 - val_accuracy: 0.9487
# Epoch 49/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.0877 - accuracy: 0.9582 - val_loss: 3.3678 - val_accuracy: 0.9231
# Epoch 50/50
# 10/10 [==============================] - 1s 51ms/step - loss: 0.5233 - accuracy: 0.9871 - val_loss: 5.2450 - val_accuracy: 0.8718

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
predicted_test = model.predict(X_test)
predicted_train = model.predict(X_train)
predicted_class = []
for i in range(len(predicted_train)):
  predicted_class.append(np.argmax(predicted_train[i]))
predicted_class_index = []
for i in range(len(predicted_test)):
  predicted_class_index.append(np.argmax(predicted_test[i]))
rounded_test = np.argmax(y_test,axis=1)
rounded_train = np.argmax(y_train,axis=1)
# Out:
# 10/10 [==============================] - 0s 16ms/step

# %%
confusion_matrix = metrics.confusion_matrix(rounded_train, predicted_class)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
confusion_matrix = metrics.confusion_matrix(rounded_test, predicted_class_index)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
print(classification_report(rounded_test, predicted_class_index))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88        46
#            1       0.78      0.97      0.86        32
#
#     accuracy                           0.87        78
#    macro avg       0.87      0.89      0.87        78
# weighted avg       0.89      0.87      0.87        78

# %%
model.save('audio_classification_model.h5')

# %%
# Load the saved model
model = load_model('audio_classification_model.h5')
# Define the target shape for input spectrograms
target_shape = (256, 256)
# Define your class labels
classes = ['Danger', 'Normal']

# %%
# Function to preprocess and classify an audio file
def test_audio(file_path, model):
    # Load and preprocess the audio file
    audio_data, sample_rate = librosa.load(file_path, sr=None)
    mel_spectrogram = librosa.feature.melspectrogram(y=audio_data, sr=sample_rate)
    mel_spectrogram = resize(np.expand_dims(mel_spectrogram, axis=-1), target_shape)
    mel_spectrogram = tf.reshape(mel_spectrogram, (1,) + target_shape + (1,))

    # Make predictions
    predictions = model.predict(mel_spectrogram)

    # Get the class probabilities
    class_probabilities = predictions[0]

    # Get the predicted class index
    predicted_class_index = np.argmax(class_probabilities)

    return class_probabilities, predicted_class_index

# %%
# Test an audio file
test_audio_file = '/content/check_danger9.mp3'
class_probabilities, predicted_class_index = test_audio(test_audio_file, model)

# Display results for all classes
for i, class_label in enumerate(classes):
    probability = class_probabilities[i]
    print(f'Class: {class_label}, Probability: {probability:.4f}')

# %%
# Calculate and display the predicted class and accuracy
predicted_class = classes[predicted_class_index]
accuracy = class_probabilities[predicted_class_index]
print(f'The audio is classified as: {predicted_class}')
print(f'Accuracy: {accuracy:.4f}')

# %% [markdown]
# #Second Model

# %%
# Model Creation
input_shape_2 = X_train[0].shape
input_layer_2 = Input(shape=input_shape_2)
x2 = Conv2D(128, (3, 3), activation='relu')(input_layer_2)
x2 = MaxPooling2D((2, 2))(x2)
x2 = Conv2D(32, (3, 3), activation='relu')(x2)
x2 = MaxPooling2D((2, 2))(x2)
x2 = Conv2D(16, (3, 3), activation='relu')(x2)
x2 = MaxPooling2D((2, 2))(x2)
x2 = Conv2D(8, (3, 3), activation='relu')(x2)
x2 = MaxPooling2D((2, 2))(x2)
x2 = Flatten()(x2)
x2 = Dense(64, activation='relu')(x2)
x2 = Dense(12, activation='relu')(x2)
output_layer_2 = Dense(len(classes), activation='softmax')(x2)
model2 = Model(input_layer_2, output_layer_2)

# %%
plot_model(model2, show_shapes=True,to_file='model2.png')

# %%
# Compile the model
model2.compile(optimizer=Adam(learning_rate=0.003), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
history2 = model2.fit(X_train, y_train, epochs=22, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/22
# 10/10 [==============================] - 3s 143ms/step - loss: 25825280.0000 - accuracy: 0.8778 - val_loss: 0.3100 - val_accuracy: 0.8846
# Epoch 2/22
# 10/10 [==============================] - 1s 106ms/step - loss: 0.6558 - accuracy: 0.9325 - val_loss: 1.0701 - val_accuracy: 0.9103
# Epoch 3/22
# 10/10 [==============================] - 1s 115ms/step - loss: 0.6253 - accuracy: 0.9550 - val_loss: 22122602.0000 - val_accuracy: 0.8718
# Epoch 4/22
# 10/10 [==============================] - 1s 105ms/step - loss: 495403584.0000 - accuracy: 0.9518 - val_loss: 0.7274 - val_accuracy: 0.9231
# Epoch 5/22
# 10/10 [==============================] - 1s 105ms/step - loss: 0.4474 - accuracy: 0.9228 - val_loss: 0.4012 - val_accuracy: 0.8718
# Epoch 6/22
# 10/10 [==============================] - 1s 117ms/step - loss: 0.2616 - accuracy: 0.9100 - val_loss: 0.3568 - val_accuracy: 0.8333
# Epoch 7/22
# 10/10 [==============================] - 1s 110ms/step - loss: 0.2008 - accuracy: 0.9100 - val_loss: 0.3243 - val_accuracy: 0.8205
# Epoch 8/22
# 10/10 [==============================] - 1s 110ms/step - loss: 0.1585 - accuracy: 0.9357 - val_loss: 0.2953 - val_accuracy: 0.8846
# Epoch 9/22
# 10/10 [==============================] - 1s 115ms/step - loss: 0.1330 - accuracy: 0.9614 - val_loss: 0.2527 - val_accuracy: 0.8846
# Epoch 10/22
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0986 - accuracy: 0.9711 - val_loss: 0.2401 - val_accuracy: 0.9103
# Epoch 11/22
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0803 - accuracy: 0.9807 - val_loss: 0.3252 - val_accuracy: 0.8974
# Epoch 12/22
# 10/10 [==============================] - 1s 106ms/step - loss: 0.0811 - accuracy: 0.9711 - val_loss: 0.2489 - val_accuracy: 0.9103
# Epoch 13/22
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0673 - accuracy: 0.9839 - val_loss: 0.2111 - val_accuracy: 0.9231
# Epoch 14/22
# 10/10 [==============================] - 1s 114ms/step - loss: 0.0834 - accuracy: 0.9807 - val_loss: 0.2518 - val_accuracy: 0.9231
# Epoch 15/22
# 10/10 [==============================] - 1s 105ms/step - loss: 0.0648 - accuracy: 0.9807 - val_loss: 0.2193 - val_accuracy: 0.9231
# Epoch 16/22
# 10/10 [==============================] - 1s 105ms/step - loss: 308122.1875 - accuracy: 0.9678 - val_loss: 1.0627 - val_accuracy: 0.8462
# Epoch 17/22
# 10/10 [==============================] - 1s 105ms/step - loss: 1.4772 - accuracy: 0.9260 - val_loss: 0.9345 - val_accuracy: 0.9103
# Epoch 18/22
# 10/10 [==============================] - 1s 115ms/step - loss: 0.3190 - accuracy: 0.9614 - val_loss: 2.3360 - val_accuracy: 0.8718
# Epoch 19/22
# 10/10 [==============================] - 1s 116ms/step - loss: 0.7214 - accuracy: 0.9164 - val_loss: 1.5032 - val_accuracy: 0.8718
# Epoch 20/22
# 10/10 [==============================] - 1s 109ms/step - loss: 0.3395 - accuracy: 0.9711 - val_loss: 0.8148 - val_accuracy: 0.9231
# Epoch 21/22
# 10/10 [==============================] - 1s 106ms/step - loss: 0.2189 - accuracy: 0.9743 - val_loss: 0.5817 - val_accuracy: 0.9487
# Epoch 22/22
# 10/10 [==============================] - 1s 104ms/step - loss: 0.0853 - accuracy: 0.9807 - val_loss: 0.4245 - val_accuracy: 0.9487

# %%
plt.plot(history2.history['accuracy'])
plt.plot(history2.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
predicted_test = model2.predict(X_test)
predicted_train = model2.predict(X_train)
predicted_class = []
for i in range(len(predicted_train)):
  predicted_class.append(np.argmax(predicted_train[i]))
predicted_class_index = []
for i in range(len(predicted_test)):
  predicted_class_index.append(np.argmax(predicted_test[i]))
rounded_test = np.argmax(y_test,axis=1)
rounded_train = np.argmax(y_train,axis=1)
# Out:
# 3/3 [==============================] - 0s 28ms/step
# 10/10 [==============================] - 0s 31ms/step

# %%
confusion_matrix = metrics.confusion_matrix(rounded_train, predicted_class)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
confusion_matrix = metrics.confusion_matrix(rounded_test, predicted_class_index)

cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)

cm_display.plot()
plt.show()

# %%
print(classification_report(rounded_test, predicted_class_index))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.93      0.96        46
#            1       0.91      0.97      0.94        32
#
#     accuracy                           0.95        78
#    macro avg       0.94      0.95      0.95        78
# weighted avg       0.95      0.95      0.95        78
